# %% [markdown]
# # IMPORTS

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd

# %% [markdown]
# # READ FILE

# %%
bankdata_Filepath=r"C:\Users\vlq927\Desktop\BDA\ct16_cap1_ds5\project_2\data\bank\bank.csv"
bank_pd =pd.read_csv(bankdata_Filepath,sep=';')
bank_pd.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
bank_pd.skew()
# Out:
# age          0.684818
# balance      8.360308
# day          0.093079
# duration     3.144318
# campaign     4.898650
# pdays        2.615715
# previous    41.846454
# dtype: float64

# %%
bank_pd.kurtosis()
# Out:
# age            0.319570
# balance      140.751547
# day           -1.059897
# duration      18.153915
# campaign      39.249651
# pdays          6.935195
# previous    4506.860660
# dtype: float64

# %%
bank_pd.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E281390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000105B02E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010545F28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000010692358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010798160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000106B8860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000109007B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010A08438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B7FEA20>]], dtype=object)

# %%
fig, ax = plt.subplots(3, figsize=(6,14))

for a,d,l in zip(range(len(ax)),
               (bank_pd
df_minmax
from sklearn import preprocessing
from pandas import DataFrame
std_scale = preprocessing.StandardScaler().fit(bank_pd[numeric_variables])
df_std = std_scale.transform(bank_pd[numeric_variables])
​
minmax_scale = preprocessing.MinMaxScaler().fit(bank_pd[numeric_variables])
df_minmax = minmax_scale.transform(bank_pd[numeric_variables])
df_minmax_T=df_minmax.T
[['age', 'balance']].values, df_std, df_minmax),
               ('Input scale',
                'Standardized [$$N  (\mu=0, \; \sigma=1)$$]',
                'min-max scaled [min=0, max=1]')
                ):
    for i,c in zip(range(1,4), ('red', 'blue', 'green')):
        ax[a].scatter(d[df['Class label'].values == i, 0],
                  d[df['Class label'].values == i, 1],
                  alpha=0.5,
                  color=c,
                  label='Class %s' %i
                  )
    ax[a].set_title(l)
    ax[a].set_xlabel('Alcohol')
    ax[a].set_ylabel('Malic Acid')
    ax[a].legend(loc='upper left')
    ax[a].grid()

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6af2d7cfb484> in <module>()
#       2
#       3 for a,d,l in zip(range(len(ax)),
# ----> 4                (bank_pd[['age', 'balance']].values, df_std, df_minmax),
#       5                ('Input scale',
#       6                 'Standardized [$$N  (\mu=0, \; \sigma=1)$$]',
#
# NameError: name 'df_std' is not defined

# %%
df_minmax
from sklearn import preprocessing
from pandas import DataFrame
std_scale = preprocessing.StandardScaler().fit(bank_pd[numeric_variables])
df_std = std_scale.transform(bank_pd[numeric_variables])
df_std_pandas=pd.DataFrame(df_std,columns=[u'age', u'balance', u'day', u'duration', u'campaign', u'pdays',u'previous'])
minmax_scale = preprocessing.MinMaxScaler().fit(bank_pd[numeric_variables])
df_minmax = minmax_scale.transform(bank_pd[numeric_variables])
df_minmax_pandas=DataFrame(df_minmax,columns=[u'age', u'balance', u'day', u'duration', u'campaign', u'pdays',u'previous'])

# %% [markdown]
# ##COVARIANCE

# %%
df_minmax_pandas.cov()
# Out:
#                age   balance       day      duration  campaign     pdays  \
# age       0.019018  0.000373 -0.000349 -3.356796e-05  0.000033 -0.000376
# balance   0.000373  0.000764  0.000035  3.120881e-05 -0.000020  0.000011
# day      -0.000349  0.000035  0.076960 -4.387984e-04  0.002252 -0.002964
# duration -0.000034  0.000031 -0.000439  2.742024e-03 -0.000221 -0.000009
# campaign  0.000033 -0.000020  0.002252 -2.212799e-04  0.002497 -0.000509
# pdays    -0.000376  0.000011 -0.002964 -9.408677e-06 -0.000509  0.013185
# previous  0.000001  0.000004 -0.000120  5.276746e-07 -0.000014  0.000437
#
#               previous
# age       1.488165e-06
# balance   3.860645e-06
# day      -1.201585e-04
# duration  5.276746e-07
# campaign -1.375126e-05
# pdays     4.374475e-04
# previous  7.015988e-05

# %% [markdown]
# #PEARSON CORRELATION COEFFICIENT

# %%
df_minmax_pandas.corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758  0.001288
# balance   0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435  0.016674
# day      -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044 -0.051710
# duration -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565  0.001203
# campaign  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628 -0.032855
# pdays    -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000  0.454820
# previous  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820  1.000000

# %% [markdown]
# #OUTLIER DETECTION

# %%
import numpy as np

df_minmax_pandas[np.abs(df_minmax_pandas.age-df_minmax_pandas.age.mean())>(3*df_minmax_pandas.age.std())] #keep only the ones that are within +3 to -3 standard deviations in the column 'Data'.
# Out:
#             age   balance       day  duration  campaign     pdays  previous
# 29158  0.844156  0.076662  0.033333  0.185441  0.000000  0.000000  0.000000
# 29261  0.740260  0.073221  0.033333  0.059780  0.000000  0.000000  0.000000
# 29263  0.740260  0.102981  0.033333  0.030297  0.000000  0.000000  0.000000
# 29322  0.844156  0.129419  0.033333  0.057544  0.016129  0.000000  0.000000
# 29865  0.740260  0.108038  0.100000  0.027654  0.032258  0.000000  0.000000
# 30908  0.753247  0.096318  0.266667  0.013827  0.177419  0.000000  0.000000
# 31051  0.844156  0.103208  0.366667  0.018097  0.000000  0.000000  0.000000
# 31055  0.870130  0.182785  0.366667  0.033550  0.016129  0.000000  0.000000
# 31069  0.935065  0.072812  0.400000  0.030907  0.032258  0.000000  0.000000
# 31089  0.831169  0.075327  0.500000  0.045344  0.096774  0.000000  0.000000
# 31099  0.714286  0.076971  0.533333  0.057137  0.000000  0.000000  0.000000
# 31101  0.727273  0.088365  0.533333  0.025824  0.000000  0.000000  0.000000
# 31116  0.740260  0.076054  0.533333  0.074014  0.161290  0.000000  0.000000
# 31125  0.779221  0.074238  0.566667  0.073200  0.000000  0.000000  0.000000
# 31130  0.870130  0.141921  0.566667  0.072184  0.032258  0.000000  0.000000
# 31145  0.805195  0.082073  0.833333  0.007523  0.000000  0.000000  0.000000
# 31151  0.779221  0.097634  0.833333  0.084994  0.016129  0.000000  0.000000
# 31183  0.714286  0.087702  0.866667  0.009963  0.016129  0.000000  0.000000
