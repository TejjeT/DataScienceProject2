# %% [markdown]
# # IMPORTS

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd

# %% [markdown]
# # READ FILE

# %%
bankdata_Filepath=r"C:\Users\vlq927\Desktop\BDA\ct16_cap1_ds5\project_2\data\bank\bank.csv"
bank_pd =pd.read_csv(bankdata_Filepath,sep=';')
numeric_variables=bank_pd.describe().columns
print numeric_variables
# Out:
# Index([u'age', u'balance', u'day', u'duration', u'campaign', u'pdays',
#        u'previous'],
#       dtype='object')

# %%
bank_pd.job.value_counts()
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64

# %%
bank_pd=bank_pd.replace(['y', 'n'],  [1, 0]) 
bank_pd=bank_pd.replace(['yes', 'no'],  [1, 0])

# %%
bank_pd.head()
# Out:
#    age           job  marital  education  default  balance  housing  loan  \
# 0   58    management  married   tertiary        0     2143        1     0
# 1   44    technician   single  secondary        0       29        1     0
# 2   33  entrepreneur  married  secondary        0        2        1     1
# 3   47   blue-collar  married    unknown        0     1506        1     0
# 4   33       unknown   single    unknown        0        1        0     0
#
#    contact  day month  duration  campaign  pdays  previous poutcome  y
# 0  unknown    5   may       261         1     -1         0  unknown  0
# 1  unknown    5   may       151         1     -1         0  unknown  0
# 2  unknown    5   may        76         1     -1         0  unknown  0
# 3  unknown    5   may        92         1     -1         0  unknown  0
# 4  unknown    5   may       198         1     -1         0  unknown  0

# %%
from sklearn import preprocessing
from pandas import DataFrame
std_scale = preprocessing.StandardScaler().fit(bank_pd[numeric_variables])
df_std = std_scale.transform(bank_pd[numeric_variables])

minmax_scale = preprocessing.MinMaxScaler().fit(bank_pd[numeric_variables])
df_minmax = minmax_scale.transform(bank_pd[numeric_variables])
df_minmax_T=df_minmax.T

# %%
pd.DataFrame(df_minmax,columns=[u'age', u'balance', u'day', u'duration', u'campaign', u'pdays',u'previous'])
# Out:
#             age   balance       day  duration  campaign     pdays  previous
# 0      0.519481  0.092259  0.133333  0.053070  0.000000  0.000000  0.000000
# 1      0.337662  0.073067  0.133333  0.030704  0.000000  0.000000  0.000000
# 2      0.194805  0.072822  0.133333  0.015453  0.000000  0.000000  0.000000
# 3      0.376623  0.086476  0.133333  0.018707  0.000000  0.000000  0.000000
# 4      0.194805  0.072812  0.133333  0.040260  0.000000  0.000000  0.000000
# 5      0.220779  0.074901  0.133333  0.028264  0.000000  0.000000  0.000000
# 6      0.129870  0.076862  0.133333  0.044124  0.000000  0.000000  0.000000
# 7      0.311688  0.072822  0.133333  0.077267  0.000000  0.000000  0.000000
# 8      0.519481  0.073902  0.133333  0.010167  0.000000  0.000000  0.000000
# 9      0.324675  0.078187  0.133333  0.011183  0.000000  0.000000  0.000000
# 10     0.298701  0.075255  0.133333  0.045140  0.000000  0.000000  0.000000
# ...

# %%
[u'age', u'balance', u'day', u'duration', u'campaign', u'pdays',
       u'previous']
# Out:
#              0         1         2         3         4         5      \
# age       0.519481  0.337662  0.194805  0.376623  0.194805  0.220779
# balance   0.092259  0.073067  0.072822  0.086476  0.072812  0.074901
# day       0.133333  0.133333  0.133333  0.133333  0.133333  0.133333
# duration  0.053070  0.030704  0.015453  0.018707  0.040260  0.028264
# campaign  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# pdays     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# previous  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#              6         7         8         9        ...        45201  \
# age       0.129870  0.311688  0.519481  0.324675    ...     0.454545
# balance   0.076862  0.072822  0.073902  0.078187    ...     0.078096
# day       0.133333  0.133333  0.133333  0.133333    ...     0.533333
# duration  0.044124  0.077267  0.010167  0.011183    ...     0.045954
# ...
