# %%
num_val='...'

max_val = 1
for i, item in enumerate(num_val):
    temp = num_val[i:(i+13)]
    if '0' not in temp:
        prod = int(temp[0])
        for s in range(12):
            prod = prod*int(temp[s+1])
        max_val = max(prod, max_val) 
print max_val
# Out:
# 23514624000
