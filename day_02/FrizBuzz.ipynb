# %%
check = 0
for i in range(1,101):
    if(i%3==0):
         check = check+1 
    if (i%5==0):
        check = check +2
    if check==0:
        print i
    elif check ==1:
        print 'Friz'
    elif check ==2:
        print 'Buzz'
    elif check ==3:
        print 'FrizBuzz'
    check=0
# Out:
# 1
# 2
# Friz
# 4
# Buzz
# Friz
# 7
# 8
# Friz
# Buzz
# 11
# Friz
# 13
# 14
# FrizBuzz
# 16
# 17
# Friz
# 19
# Buzz
# Friz
# 22
# 23
# Friz
# Buzz
# 26
# Friz
# 28
# 29
# FrizBuzz
# 31
# 32
# Friz
# 34
# Buzz
# Friz
# 37
# 38
# Friz
# Buzz
# 41
# Friz
# 43
# 44
# FrizBuzz
# 46
# 47
# Friz
# 49
# Buzz
# Friz
# 52
# 53
# Friz
# Buzz
# 56
# Friz
# 58
# 59
# FrizBuzz
# 61
# 62
# Friz
# 64
# Buzz
# Friz
# 67
# 68
# Friz
# Buzz
# 71
# Friz
# 73
# 74
# FrizBuzz
# 76
# 77
# Friz
# 79
# Buzz
# Friz
# 82
# 83
# Friz
# Buzz
# 86
# Friz
# 88
# 89
# FrizBuzz
# 91
# 92
# Friz
# 94
# Buzz
# Friz
# 97
# 98
# Friz
# Buzz
